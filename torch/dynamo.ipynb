# %%
from typing import List
import logging
import torch
import torch._dynamo as dynamo

def my_compiler(gm: torch.fx.GraphModule, example_inputs: List[torch.Tensor]):
    print("my_compiler() called with FX graph:")
    gm.graph.print_tabular()
    return gm.forward

@dynamo.optimize(my_compiler)
def foo(a, b):
    x = a / (torch.abs(a) + 1)
    if b.sum() < 0:
        b = b * -1
    return x * b
    
foo(torch.randn(10), torch.randn(10))
# Out:
# my_compiler() called with FX graph:
# `print_tabular` relies on the library `tabulate`, which could not be found on this machine. Run `pip install tabulate` to install the library.
# ---------------------------------------------------------------------------
# BackendCompilerFailed                     Traceback (most recent call last)
# Cell In[1], line 18
#      15         b = b * -1
#      16         return x * b
# ---> 18 foo(torch.randn(10), torch.randn(10))
#
# File ~/.conda/envs/ros-py38/lib/python3.8/site-packages/torch/_dynamo/eval_frame.py:433, in _TorchDynamoContext.__call__.<locals>._fn(*args, **kwargs)
#     428 saved_dynamic_layer_stack_depth = (
#     429     torch._C._functorch.get_dynamic_layer_stack_depth()
#     430 )
#     432 try:
# --> 433     return fn(*args, **kwargs)
#     434 finally:
#     435     # Restore the dynamic layer stack depth if necessary.
#     436     torch._C._functorch.pop_dynamic_layer_stack_and_undo_to_depth(
#     437         saved_dynamic_layer_stack_depth
#     438     )
#
# File ~/.conda/envs/ros-py38/lib/python3.8/site-packages/torch/_dynamo/convert_frame.py:1116, in CatchErrorsWrapper.__call__(self, frame, cache_entry, frame_state)
#    1110             return hijacked_callback(
#    1111                 frame, cache_entry, self.hooks, frame_state
#    1112             )
#    1114 with compile_lock, _disable_current_modes():
#    1115     # skip=1: skip this frame
# -> 1116     return self._torchdynamo_orig_callable(
#    1117         frame, cache_entry, self.hooks, frame_state, skip=1
#    1118     )
#
# File ~/.conda/envs/ros-py38/lib/python3.8/site-packages/torch/_dynamo/convert_frame.py:948, in ConvertFrame.__call__(self, frame, cache_entry, hooks, frame_state, skip)
#     946 counters["frames"]["total"] += 1
#     947 try:
# --> 948     result = self._inner_convert(
#     949         frame, cache_entry, hooks, frame_state, skip=skip + 1
#     950     )
#     951     counters["frames"]["ok"] += 1
#     952     return result
#
# File ~/.conda/envs/ros-py38/lib/python3.8/site-packages/torch/_dynamo/convert_frame.py:472, in ConvertFrameAssert.__call__(self, frame, cache_entry, hooks, frame_state, skip)
#     458 compile_id = CompileId(frame_id, frame_compile_id)
#     460 signpost_event(
#     461     "dynamo",
#     462     "_convert_frame_assert._compile",
#    (...)
#     469     },
#     470 )
# --> 472 return _compile(
#     473     frame.f_code,
#     474     frame.f_globals,
#     475     frame.f_locals,
#     476     frame.f_builtins,
#     477     self._torchdynamo_orig_callable,
#     478     self._one_graph,
#     479     self._export,
#     480     self._export_constraints,
#     481     hooks,
#     482     cache_entry,
#     483     cache_size,
#     484     frame,
#     485     frame_state=frame_state,
#     486     compile_id=compile_id,
#     487     skip=skip + 1,
#     488 )
#
# File ~/.conda/envs/ros-py38/lib/python3.8/site-packages/torch/_utils_internal.py:84, in compile_time_strobelight_meta.<locals>.compile_time_strobelight_meta_inner.<locals>.wrapper_function(*args, **kwargs)
#      82 if "skip" in kwargs:
#      83     kwargs["skip"] = kwargs["skip"] + 1
# ---> 84 return StrobelightCompileTimeProfiler.profile_compile_time(
#      85     function, phase_name, *args, **kwargs
#      86 )
#
# File ~/.conda/envs/ros-py38/lib/python3.8/site-packages/torch/_strobelight/compile_time_profiler.py:129, in StrobelightCompileTimeProfiler.profile_compile_time(cls, func, phase_name, *args, **kwargs)
#     124 @classmethod
#     125 def profile_compile_time(
#     126     cls, func: Any, phase_name: str, *args: Any, **kwargs: Any
#     127 ) -> Any:
#     128     if not cls.enabled:
# --> 129         return func(*args, **kwargs)
#     131     if cls.profiler is None:
#     132         logger.error("profiler is not set")
#
# File ~/.conda/envs/ros-py38/lib/python3.8/contextlib.py:75, in ContextDecorator.__call__.<locals>.inner(*args, **kwds)
#      72 @wraps(func)
#      73 def inner(*args, **kwds):
#      74     with self._recreate_cm():
# ---> 75         return func(*args, **kwds)
#
# File ~/.conda/envs/ros-py38/lib/python3.8/site-packages/torch/_dynamo/convert_frame.py:817, in _compile(code, globals, locals, builtins, compiler_fn, one_graph, export, export_constraints, hooks, cache_entry, cache_size, frame, frame_state, compile_id, skip)
#     815 guarded_code = None
#     816 try:
# --> 817     guarded_code = compile_inner(code, one_graph, hooks, transform)
#     818     return guarded_code
#     819 except (
#     820     Unsupported,
#     821     TorchRuntimeError,
#    (...)
#     828     BisectValidationException,
#     829 ) as e:
#
# File ~/.conda/envs/ros-py38/lib/python3.8/site-packages/torch/_dynamo/utils.py:231, in dynamo_timed.<locals>.dynamo_timed_inner.<locals>.time_wrapper(*args, **kwargs)
#     229 with torch.profiler.record_function(f"{key} (dynamo_timed)"):
#     230     t0 = time.time()
# --> 231     r = func(*args, **kwargs)
#     232     time_spent = time.time() - t0
#     233 compilation_time_metrics[key].append(time_spent)
#
# File ~/.conda/envs/ros-py38/lib/python3.8/site-packages/torch/_dynamo/convert_frame.py:636, in _compile.<locals>.compile_inner(code, one_graph, hooks, transform)
#     634 CompileContext.get().attempt = attempt
#     635 try:
# --> 636     out_code = transform_code_object(code, transform)
#     637     break
#     638 except exc.RestartAnalysis as e:
#
# File ~/.conda/envs/ros-py38/lib/python3.8/site-packages/torch/_dynamo/bytecode_transformation.py:1185, in transform_code_object(code, transformations, safe)
#    1182 instructions = cleaned_instructions(code, safe)
#    1183 propagate_line_nums(instructions)
# -> 1185 transformations(instructions, code_options)
#    1186 return clean_and_assemble_instructions(instructions, keys, code_options)[1]
#
# File ~/.conda/envs/ros-py38/lib/python3.8/site-packages/torch/_dynamo/convert_frame.py:178, in preserve_global_state.<locals>._fn(*args, **kwargs)
#     176 cleanup = setup_compile_debug()
#     177 try:
# --> 178     return fn(*args, **kwargs)
#     179 finally:
#     180     cleanup.close()
#
# File ~/.conda/envs/ros-py38/lib/python3.8/site-packages/torch/_dynamo/convert_frame.py:582, in _compile.<locals>.transform(instructions, code_options)
#     580 try:
#     581     with tracing(tracer.output.tracing_context), tracer.set_current_tx():
# --> 582         tracer.run()
#     583 except exc.UnspecializeRestartAnalysis:
#     584     speculation_log.clear()
#
# File ~/.conda/envs/ros-py38/lib/python3.8/site-packages/torch/_dynamo/symbolic_convert.py:2451, in InstructionTranslator.run(self)
#    2450 def run(self):
# -> 2451     super().run()
#
# File ~/.conda/envs/ros-py38/lib/python3.8/site-packages/torch/_dynamo/symbolic_convert.py:893, in InstructionTranslatorBase.run(self)
#     891 try:
#     892     self.output.push_tx(self)
# --> 893     while self.step():
#     894         pass
#     895 except BackendCompilerFailed:
#
# File ~/.conda/envs/ros-py38/lib/python3.8/site-packages/torch/_dynamo/symbolic_convert.py:805, in InstructionTranslatorBase.step(self)
#     802 self.update_block_stack(inst)
#     804 try:
# --> 805     self.dispatch_table[inst.opcode](self, inst)
#     806     return not self.output.should_exit
#     807 except exc.ObservedException:
#
# File ~/.conda/envs/ros-py38/lib/python3.8/site-packages/torch/_dynamo/symbolic_convert.py:410, in generic_jump.<locals>.inner(self, inst)
#     406         self.jump(inst)
#     407 elif (
#     408     isinstance(value, (TensorVariable)) and self.should_compile_partial_graph()
#     409 ):
# --> 410     jump_graph_break(self, inst, value)
#     411 elif isinstance(value, NNModuleVariable):
#     412     # Equivalent of "self.nn_module is not None"
#     413     mod = self.output.get_submodule(value.module_key)
#
# File ~/.conda/envs/ros-py38/lib/python3.8/site-packages/torch/_dynamo/symbolic_convert.py:324, in generic_jump.<locals>.jump_graph_break(self, inst, value, extra_msg)
#     322 self.push(value)
#     323 log.debug("generic_jump triggered compile")
# --> 324 self.output.compile_subgraph(
#     325     self,
#     326     reason=GraphCompileReason(
#     327         f"generic_jump {typestr(value)}{extra_msg}", [self.frame_summary()]
#     328     ),
#     329 )
#     330 self.pop()
#     332 if_next = self.create_call_resume_at(self.next_instruction)
#
# File ~/.conda/envs/ros-py38/lib/python3.8/site-packages/torch/_dynamo/output_graph.py:1098, in OutputGraph.compile_subgraph(self, tx, partial_convert, reason)
#    1095 append_prefix_insts()
#    1096 # optimization to generate better code in a common case
#    1097 self.add_output_instructions(
# -> 1098     self.compile_and_call_fx_graph(tx, list(reversed(stack_values)), root)
#    1099     + [create_instruction("UNPACK_SEQUENCE", arg=len(stack_values))]
#    1100 )
#    1101 # restore all the live local vars
#    1102 self.add_output_instructions(
#    1103     [PyCodegen(tx).create_store(var) for var in reversed(restore_vars)]
#    1104 )
#
# File ~/.conda/envs/ros-py38/lib/python3.8/contextlib.py:75, in ContextDecorator.__call__.<locals>.inner(*args, **kwds)
#      72 @wraps(func)
#      73 def inner(*args, **kwds):
#      74     with self._recreate_cm():
# ---> 75         return func(*args, **kwds)
#
# File ~/.conda/envs/ros-py38/lib/python3.8/site-packages/torch/_dynamo/output_graph.py:1318, in OutputGraph.compile_and_call_fx_graph(self, tx, rv, root)
#    1315     self.tracing_context.fake_mode = backend_fake_mode
#    1317 with self.restore_global_state():
# -> 1318     compiled_fn = self.call_user_compiler(gm)
#    1320 from torch.fx._lazy_graph_module import _LazyGraphModule
#    1322 if isinstance(compiled_fn, _LazyGraphModule) or (
#    1323     isinstance(getattr(compiled_fn, "__self__", None), _LazyGraphModule)
#    1324     and compiled_fn.__name__ == "_lazy_forward"
#    (...)
#    1328     # this is a _LazyGraphModule. This makes it easier for dynamo to
#    1329     # optimize a _LazyGraphModule.
#
# File ~/.conda/envs/ros-py38/lib/python3.8/site-packages/torch/_dynamo/utils.py:231, in dynamo_timed.<locals>.dynamo_timed_inner.<locals>.time_wrapper(*args, **kwargs)
#     229 with torch.profiler.record_function(f"{key} (dynamo_timed)"):
#     230     t0 = time.time()
# --> 231     r = func(*args, **kwargs)
#     232     time_spent = time.time() - t0
#     233 compilation_time_metrics[key].append(time_spent)
#
# File ~/.conda/envs/ros-py38/lib/python3.8/site-packages/torch/_dynamo/output_graph.py:1409, in OutputGraph.call_user_compiler(self, gm)
#    1407     raise e
#    1408 except Exception as e:
# -> 1409     raise BackendCompilerFailed(self.compiler_fn, e).with_traceback(
#    1410         e.__traceback__
#    1411     ) from None
#    1413 signpost_event(
#    1414     "dynamo",
#    1415     "OutputGraph.call_user_compiler",
#    (...)
#    1421     },
#    1422 )
#    1424 return compiled_fn
#
# File ~/.conda/envs/ros-py38/lib/python3.8/site-packages/torch/_dynamo/output_graph.py:1390, in OutputGraph.call_user_compiler(self, gm)
#    1388 if config.verify_correctness:
#    1389     compiler_fn = WrapperBackend(compiler_fn)
# -> 1390 compiled_fn = compiler_fn(gm, self.example_inputs())
#    1391 _step_logger()(logging.INFO, f"done compiler function {name}")
#    1392 assert callable(compiled_fn), "compiler_fn did not return callable"
#
# File ~/.conda/envs/ros-py38/lib/python3.8/site-packages/torch/_dynamo/repro/after_dynamo.py:129, in WrapBackendDebug.__call__(self, gm, example_inputs, **kwargs)
#     127             raise
#     128 else:
# --> 129     compiled_gm = compiler_fn(gm, example_inputs)
#     131 return compiled_gm
#
# Cell In[1], line 8, in my_compiler(gm, example_inputs)
#       6 def my_compiler(gm: torch.fx.GraphModule, example_inputs: List[torch.Tensor]):
#       7     print("my_compiler() called with FX graph:")
# ----> 8     gm.graph.print_tabular()
#       9     return gm.forward
#
# File ~/.conda/envs/ros-py38/lib/python3.8/site-packages/torch/fx/graph.py:1466, in Graph.print_tabular(self)
#    1460 """
#    1461 Prints the intermediate representation of the graph in tabular
#    1462 format. Note that this API requires the ``tabulate`` module to be
#    1463 installed.
#    1464 """
#    1465 try:
# -> 1466     from tabulate import tabulate
#    1467 except ImportError:
#    1468     print("`print_tabular` relies on the library `tabulate`, "
#    1469           "which could not be found on this machine. Run `pip "
#    1470           "install tabulate` to install the library.")
#
# BackendCompilerFailed: backend='my_compiler' raised:
# ModuleNotFoundError: No module named 'tabulate'
#
# Set TORCH_LOGS="+dynamo" and TORCHDYNAMO_VERBOSE=1 for more information
#
#
# You can suppress this exception and fall back to eager by setting:
#     import torch._dynamo
#     torch._dynamo.config.suppress_errors = True
