# %%
import gym
import numpy as np
import time
env = gym.make('FrozenLake-v0')

def choose_action(Q, s):
    epsilon = 0.3
    p = np. random. uniform( low=0, high=1)
    #print( p)
    if p > epsilon:
        return np. argmax( Q[s, : ] ) #say here, initial policy = for each state consider the action having highest Q- value
    else:
        return env. action_space. sample( )
    
#相关参数
lr = 0.8 #学习率
y = 0.95 #衰减因子
eps = 2000 #学习回合数
Q_table = np.zeros([env.observation_space.n,env.action_space.n])

for i in range(eps):
    s = env.reset()
    t = False
    j = 0
    while(j < 99):
        j+=1
        a = choose_action(Q_table, s)
        s_, r, t, _ = env.step(a)
        if r==0:
            if t==True:
                r = -5
                Q_table[s_] = np.ones(env.action_space.n)*r
            else:
                r = -1
        if r==1:
            r = 100
            Q_table[s_] = np.ones(env.action_space.n)*r
        Q_table[s,a] = Q_table[s,a] + lr * (r + y*np.max(Q_table[s_,:]) - Q_table[s,a])
        s = s_
        if t == True:
            break

print("Q-table")
print(Q_table)
print()

s = env.reset()
env.render()

while(True):
    print("=======")
    a = np.argmax(Q_table[s])
    print('s',s)
    print('a',a)
    s_,r,t,_ = env.step(a)
    env.render()
    s = s_
    if t==True:
        break
# Out:
# [2018-12-02 00:22:21,922] Making new env: FrozenLake-v0
# Q-table
# [[-17.38965497 -10.96524321 -13.92294409 -19.9038122 ]
#  [-11.02417154 -12.23963837 -14.13872671 -19.88543518]
#  [-15.0637655  -12.74991269 -13.83096777 -19.84696948]
#  [-12.75877056 -12.39927635  -9.88120326 -19.85799125]
#  [-17.23848921  -9.83319132 -14.19693957 -19.81312376]
#  [ -5.          -5.          -5.          -5.        ]
#  [-14.7133338  -12.20853636 -13.33368439 -19.45304054]
#  [ -5.          -5.          -5.          -5.        ]
#  [-15.98986689 -11.11493193 -14.07069492 -13.42512445]
#  [-11.96976634  -3.82603316 -12.43894691 -13.1027952 ]
#  [-14.13699677  -9.93414422 -12.27767725 -13.37357856]
#  [ -5.          -5.          -5.          -5.        ]
#  [ -5.          -5.          -5.          -5.        ]
#  [-11.89594467   0.47130538 -11.54396369 -11.97567148]
#  [-14.04257757   2.0006385   19.07981107  -6.84477654]
#  [100.         100.         100.         100.        ]]
#
#
# SFFF
# FHFH
# FFFH
# HFFG
# =======
# s 0
# a 1
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# =======
# s 0
# a 1
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# =======
# s 1
# a 0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# =======
# s 0
# a 1
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# =======
# s 1
# a 0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# =======
# s 0
# a 1
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# =======
# s 0
# a 1
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# =======
# s 1
# a 0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# =======
# s 0
# a 1
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# =======
# s 0
# a 1
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# =======
# s 0
# a 1
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# =======
# s 4
# a 1
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# =======
# s 4
# a 1
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
